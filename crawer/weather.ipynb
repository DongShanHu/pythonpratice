# %%
import pandas
import requests 
from bs4 import BeautifulSoup
from urllib.request import urlretrieve
import re

target_url = "https://www.msn.com/zh-tw/weather/news"
print('Start parsing  weather....')
rs = requests.session()
res = rs.get(target_url, verify=False)
soup = BeautifulSoup(res.text, 'html.parser')
content = ""
index =0
print(soup)
# Out:
# Start parsing  weather....
# D:\Anaconda\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# <?xml version="1.0" encoding="UTF-8" ?>
# <!DOCTYPE HTML PUBLIC "-//WAPFORUM//DTD XHTML Mobile 1.2//EN" "http://www.openmobilealliance.org/tech/DTD/xhtml-mobile12.dtd">
#
# <html dir="ltr" xml:lang="zh-TW" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# ...

# %%
for data in soup.select("div.normalsection li a"):
    title = data.text
    link = 'http://www.msn.com/' + data['href']
    content += "{}/n{}/n".format(title,link)
    print(title)
# Out:
# 明晚恐下探10度！氣象局發低溫特報
#
#
# 三月還有冷氣團？沒錯！今晚鋒面來襲
#
#
# 放晴 強烈大陸冷氣團8日報到
#
#
# 地牛翻身！宜蘭發生規模4.8地震 最大震度3級
#
#
# 低溫下探10度 新北啟動防寒機制
#
#
# 滾軸雲異象宛如電影特效 民眾稱奇
#
#
# 中市列高接梨穗災害地區 可申請現金救助
#
#
# 北台灣濕涼 8日強烈大陸冷氣團探9度
#
#
# 蔡榮根觀點：氣象局該對「地震達人」開鍘嗎 ?
#
#
# 中市高接梨穗農損災 可申請現金救助
#
#
# 氣象局上修0206六花蓮地震規模至6.26
#
#
# 日本氣象協會預測 台北下周低溫5度
#
#
# 6日雙北高溫降10度 9日恐有冷氣團
#
#
# 把握好天氣 5日起鋒面接近轉有雨
#
#
# 今日天氣／把握周末好天氣 周一又要變天

# %%
import requests 
from bs4 import BeautifulSoup
from lxml import etree
from urllib.request import urlretrieve
import re    #import 爬蟲的 library

target_url = "https://www.cwb.gov.tw/V7/observe/rainfall/hk.htm"
print('Start parsing  weather....')
rs = requests.session()
res = rs.get(target_url, verify=False)
soup = BeautifulSoup(res.text, 'html.parser')
count = 0
for data in page.xpath(u"//img/@src"):
     try:
            img_request = urllib2.Request(url)
            img_response = urllib2.urlopen(img_request)
            img = img_response.read()
    except:
        continue

    count = count+1
    filename = str(count)+".jpg"
    pic_out = file(filename,'w')
    pic_out.write(img)
    pic_out.close()
# Out:
#   File "<tokenize>", line 18
#     except:
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
  try:
            img_request = urllib2.Request(url)
            img_response = urllib2.urlopen(img_request)
            img = img_response.read()
        except:
            continue

        count = count+1
        filename = str(count)+".jpg"
        pic_out = file(filename,'w')
        pic_out.write(img)
        pic_out.close()

# %%
import pandas
import requests 
from bs4 import BeautifulSoup
from urllib.request import urlretrieve
import re

target_url = "https://www.cwb.gov.tw/V7/observe/rainfall/hk.htm"
print('Start parsing  weather....')
rs = requests.session()
res = rs.get(target_url, verify=False)
soup = BeautifulSoup(res.text, 'html.parser')
content = ""
index =0
print(soup)
# Out:
# Start parsing  weather....
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 Transitional//EN" "https://www.w3.org/TR/xhtml1/DTD/xhtml1-transitional.dtd">
#
# <html xmlns="https://www.w3.org/1999/xhtml">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <!-- Facebook -->
# <meta content="https://www.cwb.gov.tw/V7/index.htm" property="og:url"/>
# <meta content="ä¸­å¤®æ°£è±¡å±å¨çè³è¨ç¶²" property="og:title"/>
# <meta content="https://www.cwb.gov.tw/V7/forecast/taiwan/Data/Forecast01.png" property="og:image"/>
# <meta content="https://www.cwb.gov.tw/V7/observe/satellite/Data/s1p/s1p.jpg" property="og:image"/>
# <meta content="æ°£è±¡å±çæ½æ¿èæ¥­åç¼å±ï¼å¨æ¨åç¾ä»£åæ°£è±¡è§æ¸¬ãç¼å±ç²¾ç·»åæ°£è±¡é å ±ãéåµå¤ååæ°£è±¡æåç®¡éï¼ä»¥æåæ°£è±¡æåæ°´æºï¼ä¸¦éæé²ç½æ¸ç½åä¿é²ç¶æ¿ç¼å±ä¹ç®æ¨ï¼çºå¥åº·å°ç£æä¾åªè³ªæ°£è±¡è³è¨ã" property="og:description"/>
# ...

# %%
#累積雨量圖
for data in soup.findAll('div  src'):
    print(data.text)

# %%
import pandas
import requests 
from bs4 import BeautifulSoup
from urllib.request import urlretrieve
import re

target_url = "http://www.cwb.gov.tw/V7/js/HDRadar_1000_n_val.js"
# print('Start parsing  weather....')
rs = requests.session()
res = rs.get(target_url, verify=False)
soup = BeautifulSoup(res.text, 'html.parser')
content = ""
index =0
print(soup)
# Out:
# var HDRadar_1000_n_val=new Array(
# new Array("2018/08/17 17:20","/V7/observe/radar/Data/HD_Radar/CV1_1000_201808171720.png"),
# new Array("2018/08/17 17:10","/V7/observe/radar/Data/HD_Radar/CV1_1000_201808171710.png"),
# new Array("2018/08/17 17:00","/V7/observe/radar/Data/HD_Radar/CV1_1000_201808171700.png"),
# new Array("2018/08/17 16:50","/V7/observe/radar/Data/HD_Radar/CV1_1000_201808171650.png"),
# new Array("2018/08/17 16:40","/V7/observe/radar/Data/HD_Radar/CV1_1000_201808171640.png"),
# new Array("2018/08/17 16:30","/V7/observe/radar/Data/HD_Radar/CV1_1000_201808171630.png"),
# new Array("2018/08/17 16:20","/V7/observe/radar/Data/HD_Radar/CV1_1000_201808171620.png"),
# new Array("2018/08/17 16:10","/V7/observe/radar/Data/HD_Radar/CV1_1000_201808171610.png"),
# new Array("2018/08/17 16:00","/V7/observe/radar/Data/HD_Radar/CV1_1000_201808171600.png"),
# new Array("2018/08/17 15:50","/V7/observe/radar/Data/HD_Radar/CV1_1000_201808171550.png"),
# ...

# %%
soup_string = str(soup)
x=soup_string[65:121]
print("https://www.cwb.gov.tw/"+x)
# Out:
# https://www.cwb.gov.tw/V7/observe/radar/Data/HD_Radar/CV1_1000_201808171720.png
